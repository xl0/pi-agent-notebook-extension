# %%
# %matplotlib inline

# %%
#!/usr/bin/env python3

import numpy as np
import torch

from lovely_numpy import lo
from lovely_tensors import lovely, monkey_patch, config
from lovely_tensors.repr_rgb import rgb

import lovely_numpy, lovely_tensors, matplotlib

print("lovely-numpy:", lovely_numpy.__version__)
print("lovely-tensors:", lovely_tensors.__version__)
print("matplotlib:", matplotlib.__version__)
print(f"Current matplotlib backend: {matplotlib.get_backend()}")

lovely_tensors.set_config(fig_close=False)  # Note: Required otherwise all figures pop up and immediately close
# Out:
# lovely-numpy: 0.2.16
# lovely-tensors: 0.1.19
# matplotlib: 3.10.6
# Current matplotlib backend: tkagg
